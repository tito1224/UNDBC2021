# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/UBDC_2021/Final/combined_df_label2.csv")
#df = df.loc[:,["text","label"]]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0 coordinates  ... user_verified label
# 0           0         NaN  ...         False     0
# 1           1         NaN  ...          True     0
# 2           2         NaN  ...         False     0
# 3           3         NaN  ...         False     0
# 4           4         NaN  ...         False     0
#
# [5 rows x 36 columns]

# %%
to_drop = df.iloc[:,[0,1]]
df.drop(to_drop, axis = 1, inplace = True)

# %%
df.created_at = pd.to_datetime(df.created_at)

# %%
df["month"] = df.created_at.dt.month
df["year"] = df.created_at.dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233106 entries, 0 to 233105
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   created_at                  233106 non-null  datetime64[ns, UTC]
#  1   hashtags                    42415 non-null   object
#  2   media                       34644 non-null   object
#  3   urls                        109285 non-null  object
#  4   favorite_count              233106 non-null  int64
#  5   id                          233106 non-null  int64
#  6   in_reply_to_screen_name     114340 non-null  object
#  7   in_reply_to_status_id       112255 non-null  float64
#  8   in_reply_to_user_id         114340 non-null  float64
#  9   lang                        233106 non-null  object
#  10  place                       4974 non-null    object
#  11  possibly_sensitive          124413 non-null  object
#  12  retweet_count               233106 non-null  int64
#  13  retweet_id                  0 non-null       float64
#  14  retweet_screen_name         0 non-null       float64
#  15  source                      233106 non-null  object
#  16  text                        233106 non-null  object
#  17  tweet_url                   233106 non-null  object
#  18  user_created_at             233106 non-null  object
#  19  user_screen_name            233106 non-null  object
#  20  user_default_profile_image  233106 non-null  bool
#  21  user_description            206823 non-null  object
#  22  user_favourites_count       233106 non-null  int64
#  23  user_followers_count        233106 non-null  int64
#  24  user_friends_count          233106 non-null  int64
#  25  user_listed_count           233106 non-null  int64
#  26  user_location               173829 non-null  object
#  27  user_name                   233094 non-null  object
#  28  user_screen_name.1          233106 non-null  object
#  29  user_statuses_count         233106 non-null  int64
#  30  user_time_zone              0 non-null       float64
#  31  user_urls                   112290 non-null  object
#  32  user_verified               233106 non-null  bool
#  33  label                       233106 non-null  int64
#  34  month                       233106 non-null  int64
#  35  year                        233106 non-null  int64
# dtypes: bool(2), datetime64[ns, UTC](1), float64(5), int64(11), object(17)
# memory usage: 60.9+ MB

# %%
lang_bool = df.lang == "en"
df = df.loc[lang_bool,:]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221461 entries, 0 to 233105
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   created_at                  221461 non-null  datetime64[ns, UTC]
#  1   hashtags                    40892 non-null   object
#  2   media                       33124 non-null   object
#  3   urls                        104470 non-null  object
#  4   favorite_count              221461 non-null  int64
#  5   id                          221461 non-null  int64
#  6   in_reply_to_screen_name     107089 non-null  object
#  7   in_reply_to_status_id       105071 non-null  float64
#  8   in_reply_to_user_id         107089 non-null  float64
#  9   lang                        221461 non-null  object
#  10  place                       4724 non-null    object
#  11  possibly_sensitive          118759 non-null  object
#  12  retweet_count               221461 non-null  int64
#  13  retweet_id                  0 non-null       float64
#  14  retweet_screen_name         0 non-null       float64
#  15  source                      221461 non-null  object
#  16  text                        221461 non-null  object
#  17  tweet_url                   221461 non-null  object
#  18  user_created_at             221461 non-null  object
#  19  user_screen_name            221461 non-null  object
#  20  user_default_profile_image  221461 non-null  bool
#  21  user_description            196747 non-null  object
#  22  user_favourites_count       221461 non-null  int64
#  23  user_followers_count        221461 non-null  int64
#  24  user_friends_count          221461 non-null  int64
#  25  user_listed_count           221461 non-null  int64
#  26  user_location               165696 non-null  object
#  27  user_name                   221449 non-null  object
#  28  user_screen_name.1          221461 non-null  object
#  29  user_statuses_count         221461 non-null  int64
#  30  user_time_zone              0 non-null       float64
#  31  user_urls                   107757 non-null  object
#  32  user_verified               221461 non-null  bool
#  33  label                       221461 non-null  int64
#  34  month                       221461 non-null  int64
#  35  year                        221461 non-null  int64
# dtypes: bool(2), datetime64[ns, UTC](1), float64(5), int64(11), object(17)
# memory usage: 59.6+ MB

# %%
df.head()
df.to_csv("/content/drive/MyDrive/UBDC_2021/Final/for_tobi.csv")
